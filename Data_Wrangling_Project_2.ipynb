# %% [markdown]
# <a href="https://colab.research.google.com/github/Deb052024/Data-Wranglling/blob/main/Data_Wrangling_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_excel('/content/dataset_1.xlsx')
df2=pd.read_excel('/content/dataset_2.xlsx')
df3=pd.read_excel('/content/dataset_3.xlsx')

# %%
df1.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp
# count  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885
# min      0.000000    0.000000    1.000000    0.020000
# 25%      6.000000    1.000000    1.000000    0.160000
# 50%     12.000000    3.000000    1.000000    0.200000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
df1.shape
# Out:
# (610, 10)

# %%
df1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
df1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.columns.unique()
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2_new=df2.drop('Unnamed: 0',axis=1)

# %%
df2_new
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
bikecount=pd.merge(df1,df2_new, on='instant',how='inner')

# %%
bikecount
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
sns.heatmap(bikecount.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(bikecount)

# %%
bikecount.isnull().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
bikecount['atemp'].fillna(bikecount['atemp'].mean(),inplace=True)

# %%
df_rev.rename(columns = {'Holliday_Package':'Holiday_Package'}, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b4855e0106d8> in <cell line: 1>()
# ----> 1 df_rev.rename(columns = {'Holliday_Package':'Holiday_Package'}, inplace = True)
#
# NameError: name 'df_rev' is not defined

# %%
bikecount.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 605    False
# 606    False
# 607    False
# 608    False
# 609    False
# Length: 610, dtype: bool

# %%
bikecount['atemp'].unique()
# Out:
# array([0.2879    , 0.2727    , 0.2576    , 0.19993489, 0.3485    ,
#        0.3939    , 0.3333    , 0.4242    , 0.4545    , 0.4394    ,
#        0.4091    , 0.2273    , 0.2121    , 0.197     , 0.1364    ,
#        0.1061    , 0.1212    , 0.1667    , 0.1818    , 0.2424    ,
#        0.1515    , 0.3182    , 0.0606    , 0.0758    , 0.0909    ,
#        0.303     , 0.0303    , 0.0455    , 0.        , 0.0152    ])

# %%
bikecount.plot(kind='scatter',x='temp',y='atemp')
# Out:
# <Axes: xlabel='temp', ylabel='atemp'>

# %%
sns.displot(bikecount['registered'],bins=5)

# %%
bikecount.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp       atemp         hum  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885    0.199935    0.562475
# min      0.000000    0.000000    1.000000    0.020000    0.000000    0.210000
# ...

# %%
bikecount.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
plt.figure(figsize=(11,13))
sns.boxplot(bikecount)
# Out:
# <Axes: >

# %%
sns.regplot(x='temp',y='registered',data=bikecount)
# Out:
# <Axes: xlabel='temp', ylabel='registered'>

# %%
sns.scatterplot(x='weekday',y='registered',data=bikecount)
# Out:
# <Axes: xlabel='weekday', ylabel='registered'>

# %%
sns.scatterplot(y='cnt',x='registered',data=bikecount)
# Out:
# <Axes: xlabel='registered', ylabel='cnt'>

# %%
sns.scatterplot(y='cnt',x='weekday',data=bikecount)
# Out:
# <Axes: xlabel='weekday', ylabel='cnt'>

# %%
sns.scatterplot(y='hr',x='registered',data=bikecount)
# Out:
# <Axes: xlabel='registered', ylabel='hr'>

# %%
sns.scatterplot(y='hr',x='casual',data=bikecount)
# Out:
# <Axes: xlabel='casual', ylabel='hr'>

# %%
plt.bar(bikecount['registered'],bikecount['cnt'])
plt.title(" Registered vs Count")
plt.xlabel("Registered")
plt.ylabel("Count")
plt.show()

# %%
plt.bar(bikecount['casual'],bikecount['cnt'])
plt.title(" Count vs Casual")
plt.xlabel("Casual")
plt.ylabel("cnt")
plt.show()

# %%
bikecount['registered'].count()
# Out:
# 610

# %%
bikecount['casual'].count()
# Out:
# 610

# %%
bikecount.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
bikecount[['weekday','hr','registered']].value_counts()
# Out:
# weekday  hr  registered
# 4        2   2             3
# 0        6   1             3
# 3        1   6             3
# 0        4   1             3
#          3   4             3
#                           ..
# 2        9   98            1
#          8   233           1
#              214           1
#              177           1
# 6        23  39            1
# Name: count, Length: 575, dtype: int64

# %%
pd.pivot_table(bikecount,'registered','hr',aggfunc='sum')
# Out:
#     registered
# hr
# 0          328
# 1          211
# 2          152
# 3           58
# 4           33
# 5           93
# 6          464
# 7         1351
# 8         3238
# 9         2093
# 10        1180
# 11        1233
# 12        1664
# 13        1732
# 14        1585
# 15        1642
# 16        1947
# 17        3342
# 18        2953
# 19        2096
# 20        1459
# 21        1007
# 22         782
# 23         509

# %%
pd.pivot_table(bikecount,'casual','hr',aggfunc='sum')
# Out:
#     casual
# hr
# 0       42
# 1       28
# 2       18
# 3       18
# 4        5
# 5        2
# 6       12
# 7       42
# 8       80
# 9      103
# 10     121
# 11     222
# 12     272
# 13     283
# 14     242
# 15     292
# 16     253
# 17     208
# 18     129
# 19     117
# 20      82
# 21      68
# 22      56
# 23      51

# %%
bikecount.plot(kind='scatter',x='temp',y='cnt')
# Out:
# <Axes: xlabel='temp', ylabel='cnt'>

# %%
bikecount.plot(kind='scatter',x='hum',y='cnt')
# Out:
# <Axes: xlabel='hum', ylabel='cnt'>

# %%
df10=bikecount.to_csv('C:\\Users\\Admin\\Downloads\\bike.csv')
#df10.to_csv('C:\\Users\\Admin\\Downloads\\file11.csv')

# %%
bikecount[['registered','hr']].value_counts()
# Out:
# registered  hr
# 1           4     13
# 2           2      7
# 1           5      6
# 3           5      5
# 1           3      5
#                   ..
# 39          10     1
#             9      1
# 38          20     1
# 37          23     1
# 247         8      1
# Name: count, Length: 459, dtype: int64

# %%
bikecount

# %%
sns.stripplot(x='weekday',y='registered',data=bikecount)
# Out:
# <Axes: xlabel='weekday', ylabel='registered'>
